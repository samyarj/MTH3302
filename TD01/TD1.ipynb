# %% [markdown]
# # MTH3302 : Méthodes probabilistes et statistiques pour l'I.A.
#
# Jonathan Jalbert<br/>
# Professeur agrégé au Département de mathématiques et de génie industriel<br/>
# Polytechnique Montréal<br/>
#
#
# # TD1 - Introduction à Julia
#
# Ce TD constitue une introduction au langage Julia et au calepin Jupyter. L'Exercice 1 a pour but d'introduire les commandes de base de Julia et de la librairie *Distributions.jl* tandis que l'Exercice 2 a pour but d'introduire les DataFrames et la puissante librairie *Gadfly.jl*, similaire à *ggplot2* en *R*, pour la création de graphiques.
#
# Commençons par charger les librairies nécessaires. Si elles ne sont pas installées, vous pouvez le faire avec les commandes suivantes :
#
# ```
# using Pkg
# Pkg.add(["CSV", "DataFrames" ,"Distributions", "Gadfly", "Statistics"])
# ```

# %%
using CSV              # Pour charger les fichiers CSV
using DataFrames       # Pour utiliser la structure DataFrame pour stocker les données
using Distributions    # Pour utiliser les lois de probabilités classiques
using Gadfly           # Pour tracer des graphiques
using Statistics       # Pour les functions statistiques de base

# %% [markdown]
# # Exercice 1
#
# Dans cet exercice, nous nous intéressons au problèmes du [collectionneur de vignettes](https://fr.wikipedia.org/wiki/Probl%C3%A8me_du_collectionneur_de_vignettes) - un problème classique en probabilités.
#
# ## Description du problème
#
# La compagnie Kinder Surprise offre des friandises avec en bonus un jouet à l'intérieur. Le jouet fait partie d'une série de 8 jouets à collectionner. Les jouets sont disposés au hasard dans la friandise et on suppose qu'à chaque achat, les probabilités d'obtenir d'obtenir chacun des éléments de la collection sont équiprobables et indépendants.
#
# Un collectionneur veut obtenir tous les 8 jouets de la collection. On s'intéresse au nombre d'achats requis pour compléter la collection.
#
# ## Modélisation mathématique
#
# Soit la variable aléatoire $T$, le nombre d'achats requis pour compléter la collection de taille $n$. Posons $T_i$, le nombre d'achats requis pour obtenir le $i^e$ élément de la collection lorsque l'on a déjà $(i-1)$ éléments de la collection. On a alors que
#
# $$ T = \sum_{i=1}^n T_i. $$
#
# On peut montrer que
#
# $$T_i \sim Géométrique( p_i )$$
#
# avec
#
# $$p_i = \frac{n-i+1}{n}.$$
#
#
# ## 1.1 Simulations Monte-Carlo
#
# Pour répondre aux questions de cet exercice, nous utiliserons une procédure Monte-Carlo qui consiste à simuler plusieurs réalisations de $T$ pour estimer les quantités d'intérêts.
#
# Voici les différentes étapes de la procédure Monte-Carlo :
# 1. Simulation du nombre d'essais requis pour obtenir la $i^e$ nouvel item de la collection.
# 2. Simulation du nombre d'essais requis pour obtenir la collection complète.
#
#
#
#
# Voici les différentes étapes qui nous permettrons d'étudier le problème :
#
# 1. Simulation du nombre d'essais requis pour obtenir la $i^e$ nouvel item de la collection.
# 2. Simulation du nombre d'essais requis pour obtenir la collection complète.
# 3. Affichage du nombre d'essais requis pour 10 000 essais afin d'obtenir la collection complète.
# 4. Estimation de la moyenne du nombre d'essais requis pour obtenir la collection complète.
# 5. Estimation de la probabilité que 100 essais soit suffisants pour obtenir la collection complète.

# %% [markdown]
# ### 1.1.1. Simulation du nombre d'essais requis pour obtenir le $i^e$ nouvel item
#
# Générez une réalisation possible du nombre d'essais requis pour obtenir le $i^e$ nouvel item d'une collection de $n$ éléments.
#
# Utilisez le constructeur `Geometric()` pour construire un objet de type loi géométrique pour ensuite utiliser la fonction `rand()`sur cet objet pour générer une réalisation.

# %%
n = 8 # Nombre d'éléments de la collection
i = 7
a = Geometric((n+1-i)/n) # = (1/n) * (1 - 1/n)^(i-1) # Loi géométrique
# générer une réalisation en utilisant la fonction rand
realisation = rand(a) + 1
println("Nombre d'essais : ", realisation)
# Out:
# Nombre d'essais : 5

# %% [markdown]
# Transformez le code précédent en fonction nommée *ntrial* qui prend en argument $i$ et la taille de collection $n$.

# %%
function ntrial(i::Int,n::Int)
   @assert 0<i<=n # Vérification de la validité de i (facultatif)
   a = Geometric((n+1-i)/n)
   res = rand(a) + 1
   return res
end
ntrial(i,n)
# Out:
# 2

# %% [markdown]
# ### 1.1.2. Simulation du nombre d'achats requis pour obtenir la collection complète.
#
# Simulez le nombre d'achats nécessaires pour obtenir la collection complète en simulant chacun de $T_i$.

# %%
res = Int[]
for j in 1:8
    push!(res, ntrial(j,n))
end
df = DataFrame(essais = res)
# Out:
# 8×1 DataFrame
#  Row │ essais
#      │ Int64
# ─────┼────────
#    1 │      1
#    2 │      1
#    3 │      1
#    4 │      1
#    5 │      1
#    6 │      2
#    7 │      2
#    8 │      4

# %% [markdown]
# Transformez le code précédent en fonction nommée *ntotal* qui prend en argument la taille de la collection.

# %%
function ntotal(n::Int)
   @assert n>0
   total=0
   for j in 1:8
    total += ntrial(j,n)
   end
   return total
end
ntotal(n)
# Out:
# 45

# %% [markdown]
# ### 1.1.3. Simulation du nombre d'achats requis pour compléter la collection.
#
# Simulez d'abord 10 000 réalisations du nombre d'achats requis pour compléter la collection. C'est comme si on répétait l'expérience de collectionner les n objets 10 000 fois.

# %%
T = Int64[]

for j in 1:10000
    push!(T, ntotal(n))
end
println(T)
# Out:
# [37, 12, 16, 19, 17, 9, 34, 18, 11, 17, 24, 18, 18, 15, 20, 14, 43, 16, 13, 19, 12, 29, 32, 11, 15, 39, 16, 10, 21, 15, 21, 28, 12, 23, 23, 23, 21, 22, 33, 22, 10, 11, 27, 12, 15, 23, 24, 18, 11, 28, 30, 9, 21, 13, 24, 21, 24, 17, 15, 15, 14, 32, 19, 23, 36, 16, 23, 20, 13, 24, 13, 15, 16, 29, 27, 16, 15, 13, 28, 14, 19, 12, 12, 22, 29, 15, 11, 23, 16, 15, 21, 22, 14, 24, 12, 13, 33, 25, 22, 22, 26, 13, 13, 16, 19, 10, 13, 23, 25, 16, 26, 29, 20, 19, 16, 20, 16, 42, 28, 12, 24, 19, 19, 13, 17, 22, 10, 13, 12, 23, 24, 17, 19, 28, 19, 24, 28, 15, 13, 19, 18, 19, 26, 19, 19, 24, 16, 13, 19, 36, 20, 23, 15, 22, 20, 12, 10, 18, 25, 27, 12, 16, 32, 22, 19, 17, 20, 19, 17, 19, 17, 25, 15, 31, 19, 16, 16, 28, 18, 18, 13, 19, 27, 25, 15, 11, 16, 14, 18, 14, 42, 28, 29, 23, 20, 19, 44, 11, 35, 30, 29, 17, 46, 23, 16, 17, 25, 25, 19, 22, 26, 19, 18, 17, 40, 36, 10, 14, 27, 30, 21, 23, 17, 26, 33, 13, 28, 17, 26, 17, 34, 20, 41, 16, 25, 22, 26, 14, 23, 16, 20, 25, 23, 14, 15, 31, 9, 17, 17, 12, 24, 14, 32, 24, 21, 16, 14, 17, 34, 21, 52, 27, 13, 11, 38, 14, 24, 13, 27, 12, 25, 23, 33, 9, 16, 17, 17, 26, 15, 21, 21, 26, 16, 23, 19, 17, 17, 15, 25, 20, 29, 21, 24, 33, 19, 25, 21, 12, 22, 14, 17, 25, 24, 13, 17, 19, 26, 20, 28, 30, 27, 41, 21, 30, 18, 15, 27, 15, 26, 14, 21, 19, 33, 18, 31, 18, 18, 44, 14, 25, 16, 18, 23, 12, 14, 21, 11, 12, 17, 46, 13, 24, 19, 18, 12, 26, 14, 36, 12, 28, 18, 28, 32, 20, 18, 11, 28, 15, 15, 35, 15, 20, 24, 22, 41, 27, 22, 21, 18, 17, 25, 18, 20, 18, 28, 27, 24, 13, 31, 13, 14, 11, 58, 17, 28, 28, 11, 17, 16, 13, 18, 32, 22, 11, 43, 16, 14, 15, 24, 22, 36, 15, 31, 18, 25, 24, 21, 15, 18, 14, 23, 17, 18, 20, 30, 26, 25, 14, 16, 15, 10, 28, 13, 25, 53, 17, 33, 16, 17, 33, 33, 28, 42, 24, 31, 14, 13, 13, 15, 13, 14, 13, 13, 17, 20, 20, 22, 16, 13, 38, 19, 10, 36, 25, 20, 21, 37, 14, 22, 28, 18, 12, 21, 27, 13, 28, 18, 12, 16, 9, 23, 31, 20, 11, 25, 20, 21, 23, 11, 32, 18, 19, 19, 11, 10, 34, 33, 23, 9, 25, 17, 19, 14, 12, 28, 18, 25, 13, 26, 18, 21, 17, 22, 30, 26, 11, 31, 23, 15, 13, 28, 15, 16, 16, 19, 36, 13, 15, 31, 33, 19, 20, 22, 25, 20, 21, 66, 37, 29, 33, 16, 19, 28, 31, 15, 15, 16, 24, 21, 15, 20, 17, 22, 32, 36, 15, 19, 27, 16, 15, 10, 24, 26, 22, 15, 15, 27, 23, 23, 22, 11, 18, 16, 31, 19, 12, 16, 9, 14, 42, 24, 15, 26, 16, 24, 23, 32, 27, 15, 23, 20, 19, 63, 15, 13, 14, 15, 37, 29, 14, 41, 17, 23, 44, 47, 22, 16, 18, 20, 21, 33, 13, 12, 35, 23, 19, 17, 22, 30, 17, 20, 12, 47, 18, 26, 16, 28, 11, 25, 15, 15, 14, 11, 16, 12, 21, 13, 21, 17, 20, 14, 12, 18, 18, 28, 26, 16, 26, 26, 36, 35, 34, 13, 32, 26, 14, 29, 21, 12, 27, 18, 28, 39, 44, 17, 26, 21, 28, 15, 28, 17, 19, 19, 22, 30, 23, 18, 25, 19, 12, 13, 26, 33, 18, 24, 24, 25, 31, 16, 21, 17, 25, 27, 32, 25, 23, 35, 12, 13, 28, 18, 16, 22, 13, 12, 26, 18, 42, 27, 21, 20, 13, 12, 15, 22, 20, 27, 12, 21, 23, 14, 18, 28, 46, 15, 13, 12, 23, 36, 12, 27, 21, 27, 38, 19, 28, 21, 10, 29, 27, 21, 27, 15, 29, 15, 18, 15, 27, 22, 15, 19, 25, 17, 23, 19, 23, 11, 14, 13, 16, 24, 16, 16, 28, 21, 17, 14, 19, 17, 14, 12, 10, 25, 23, 14, 24, 55, 13, 29, 19, 15, 22, 12, 18, 17, 20, 23, 13, 24, 16, 29, 19, 22, 17, 13, 19, 30, 19, 23, 26, 23, 18, 50, 16, 21, 11, 14, 21, 16, 44, 19, 23, 66, 23, 31, 11, 24, 13, 13, 13, 18, 15, 18, 17, 20, 13, 13, 20, 31, 16, 30, 19, 16, 26, 19, 18, 16, 22, 36, 21, 33, 11, 12, 12, 16, 29, 24, 27, 17, 20, 24, 19, 24, 23, 25, 11, 16, 18, 12, 12, 17, 27, 22, 15, 34, 22, 11, 26, 16, 29, 39, 15, 22, 31, 22, 20, 20, 20, 14, 14, 19, 24, 19, 15, 10, 30, 14, 15, 11, 21, 22, 17, 20, 22, 13, 33, 29, 22, 15, 24, 17, 21, 27, 35, 13, 17, 18, 28, 22, 14, 16, 30, 30, 18, 20, 22, 28, 20, 22, 9, 30, 35, 35, 26, 34, 22, 15, 15, 24, 21, 17, 19, 19, 19, 22, 40, 15, 23, 20, 28, 12, 41, 26, 28, 18, 17, 21, 17, 17, 15, 28, 18, 19, 21, 22, 22, 15, 23, 47, 22, 16, 22, 17, 39, 31, 28, 16, 15, 40, 29, 21, 23, 16, 21, 32, 14, 11, 36, 21, 18, 37, 27, 13, 24, 15, 16, 17, 22, 21, 29, 16, 20, 30, 20, 17, 17, 13, 25, 11, 13, 14, 18, 20, 12, 35, 36, 19, 14, 14, 10, 17, 30, ...

# %% [markdown]
# Affichez le nombre d'essais requis avec un histogramme à 100 classes en utilisant l'argument `Geom.histogram(bincount=100)` de la fonction `plot()` de la librairie Gadfly.

# %%
# https://docs.juliaplots.org/dev/series_types/histogram/
Geom.histogram(bincount=100)
plot(layer(x=T, Geom.histogram(bincount=100)), 
     Guide.xlabel("Nombre total d'essais"), 
     Guide.ylabel("Fréquence de succès"),
     Guide.title("Histogramme du nombre total d'essais pour collecter les 8 éléments"))
# Out:
# Plot(...)

# %% [markdown]
# ## 1.2 Estimation Monte-Carlo des quantités d'intérêt
#
# On utilisera l'ensemble des réalisations simulées pour estimer les quantités d'intérêt.

# %% [markdown]
# ### 1.2.1. Estimation de l'espérance du nombre d'achats requis pour obtenir la collection complète.
#
# À l'aide des 10 000 réalisations, calculez la moyenne empirique de nombre d'essais requis pour obtenir la collection complète de $n=8$ éléments.

# %%
println(mean(T))
# Out:
# 21.8306

# %% [markdown]
# ### 1.2.2. Estimation de l'écart-type du nombre d'achats requis pour obtenir la collection complète.
#
# À l'aide des 10 000 réalisations, calculez l'écart-type empirique de nombre d'essais requis pour obtenir la collection complète de $n=8$ éléments.

# %%
std(T)
# Out:
# 8.80997532383154

# %% [markdown]
# ### 1.2.2. Estimation de la probabilité que 23 essais soit suffisants pour obtenir la collection complète.
#
# Pour ce faire, calculez la proportion empirique des réalisations parmi les 10 000 simulées où 23 essais ou moins ont été suffisants pour compléter la collection.

# %%
K = Int64[]

for j in 1:10000
    essaie = ntotal(n)
    if essaie <= 23
        push!(K, essaie)
    end
end
println(length(K)/10000, K)

Geom.histogram(bincount=100)
plot(layer(x=K, Geom.histogram(bincount=100)), 
     Guide.xlabel("Nombre total d'essais"), 
     Guide.ylabel("Fréquence de succès"),
     Guide.title("Histogramme du nombre total d'essais pour collecter les 8 éléments"))
# Out:
# 0.6662[17, 19, 13, 13, 17, 22, 14, 19, 14, 12, 16, 22, 23, 16, 21, 19, 19, 20, 14, 19, 13, 20, 13, 18, 18, 16, 15, 22, 19, 17, 18, 10, 13, 20, 21, 15, 14, 14, 18, 11, 23, 16, 23, 19, 15, 18, 20, 11, 20, 15, 16, 17, 13, 16, 9, 18, 11, 19, 22, 20, 23, 16, 19, 17, 14, 14, 9, 18, 14, 23, 23, 20, 17, 21, 15, 23, 16, 22, 14, 17, 9, 23, 16, 21, 16, 13, 23, 15, 23, 18, 18, 12, 14, 16, 22, 10, 17, 12, 20, 20, 17, 13, 16, 20, 23, 16, 19, 13, 15, 23, 22, 11, 22, 23, 17, 20, 14, 16, 20, 14, 13, 21, 23, 21, 11, 15, 21, 18, 20, 19, 14, 20, 20, 18, 22, 19, 12, 13, 11, 16, 10, 20, 14, 19, 17, 15, 14, 19, 17, 21, 13, 16, 11, 18, 23, 16, 21, 22, 17, 21, 12, 16, 12, 18, 16, 15, 23, 15, 9, 14, 19, 23, 17, 18, 13, 14, 13, 17, 22, 21, 14, 17, 10, 18, 19, 15, 19, 16, 18, 13, 13, 21, 17, 11, 17, 16, 15, 22, 20, 15, 15, 21, 16, 17, 17, 18, 14, 13, 12, 21, 21, 23, 11, 19, 18, 20, 23, 19, 14, 12, 14, 17, 19, 22, 12, 17, 17, 21, 22, 14, 22, 11, 18, 23, 15, 11, 11, 19, 17, 19, 22, 17, 19, 23, 14, 13, 12, 22, 17, 19, 14, 11, 20, 11, 14, 23, 15, 19, 13, 21, 13, 19, 22, 16, 21, 14, 14, 19, 14, 18, 19, 13, 22, 21, 14, 16, 14, 18, 20, 22, 18, 15, 20, 13, 13, 18, 20, 17, 14, 17, 20, 22, 16, 23, 11, 14, 16, 20, 15, 19, 14, 17, 19, 14, 15, 16, 16, 18, 22, 23, 16, 18, 13, 12, 19, 14, 23, 21, 11, 11, 17, 15, 11, 16, 18, 18, 18, 22, 15, 19, 19, 22, 14, 21, 21, 13, 15, 14, 14, 22, 15, 16, 20, 17, 20, 23, 18, 13, 12, 23, 15, 20, 21, 22, 18, 14, 16, 12, 23, 20, 20, 22, 17, 21, 20, 14, 15, 20, 16, 22, 23, 12, 18, 22, 22, 18, 13, 19, 12, 13, 14, 20, 19, 18, 21, 19, 19, 12, 18, 10, 20, 16, 22, 14, 22, 19, 15, 15, 20, 17, 12, 19, 19, 12, 15, 16, 16, 11, 18, 14, 9, 23, 18, 23, 20, 20, 13, 18, 18, 10, 17, 18, 16, 17, 19, 21, 17, 23, 8, 22, 14, 17, 23, 13, 20, 18, 18, 20, 23, 14, 18, 22, 21, 18, 18, 22, 13, 18, 22, 23, 9, 16, 14, 17, 10, 19, 10, 14, 15, 15, 17, 16, 9, 15, 21, 12, 21, 12, 12, 13, 10, 14, 20, 21, 14, 19, 18, 19, 16, 20, 16, 18, 17, 14, 23, 17, 23, 13, 23, 21, 19, 17, 14, 20, 13, 17, 10, 21, 19, 20, 13, 17, 22, 14, 18, 20, 23, 19, 17, 21, 15, 17, 16, 17, 18, 12, 14, 18, 21, 13, 13, 14, 17, 21, 18, 15, 21, 11, 13, 15, 22, 23, 13, 17, 14, 12, 23, 13, 14, 15, 23, 15, 15, 9, 8, 16, 22, 13, 15, 18, 14, 11, 22, 18, 18, 19, 16, 21, 15, 16, 14, 21, 18, 16, 15, 13, 13, 14, 15, 22, 20, 20, 21, 16, 23, 21, 12, 15, 17, 17, 16, 18, 22, 13, 19, 18, 18, 13, 11, 15, 23, 8, 20, 19, 15, 20, 19, 19, 18, 17, 15, 17, 18, 17, 12, 10, 13, 19, 13, 21, 10, 16, 19, 19, 16, 16, 19, 17, 20, 17, 15, 20, 20, 13, 9, 18, 20, 22, 14, 14, 17, 22, 16, 14, 22, 8, 15, 21, 17, 22, 11, 19, 23, 17, 17, 19, 9, 14, 20, 12, 17, 16, 10, 17, 16, 11, 16, 12, 10, 16, 16, 12, 19, 14, 14, 15, 19, 20, 20, 21, 23, 20, 14, 12, 18, 15, 15, 12, 21, 16, 17, 20, 17, 12, 19, 19, 23, 22, 18, 15, 16, 19, 14, 13, 15, 12, 21, 23, 21, 17, 12, 19, 14, 20, 17, 13, 16, 22, 21, 13, 13, 12, 16, 10, 15, 22, 19, 21, 14, 12, 18, 22, 10, 14, 18, 19, 10, 14, 16, 17, 23, 15, 17, 12, 22, 16, 17, 13, 15, 16, 15, 21, 14, 13, 21, 16, 15, 13, 13, 19, 20, 14, 18, 23, 21, 20, 16, 17, 12, 20, 14, 17, 17, 14, 14, 11, 19, 12, 11, 15, 14, 17, 10, 18, 12, 18, 15, 20, 11, 15, 20, 12, 9, 22, 16, 18, 21, 13, 18, 16, 19, 13, 19, 17, 13, 23, 16, 16, 15, 14, 23, 14, 22, 13, 21, 17, 22, 22, 16, 16, 23, 18, 10, 19, 22, 19, 16, 21, 20, 21, 17, 23, 21, 10, 15, 12, 11, 15, 19, 20, 18, 22, 16, 22, 20, 21, 16, 19, 16, 20, 18, 14, 17, 23, 22, 23, 18, 19, 13, 22, 19, 23, 17, 23, 16, 22, 19, 20, 18, 14, 9, 23, 12, 21, 22, 13, 22, 20, 18, 16, 13, 17, 13, 13, 21, 16, 15, 15, 21, 9, 22, 19, 11, 20, 14, 16, 18, 18, 13, 22, 20, 15, 16, 15, 22, 16, 14, 18, 11, 14, 18, 21, 14, 17, 19, 19, 20, 19, 15, 14, 17, 16, 9, 22, 15, 17, 21, 19, 13, 12, 11, 22, 21, 9, 14, 19, 13, 20, 16, 19, 13, 19, 13, 22, 17, 21, 15, 19, 17, 23, 16, 21, 23, 18, 22, 16, 22, 14, 13, 22, 9, 17, 18, 12, 21, 15, 12, 13, 11, 10, 16, 12, 20, 23, 12, 20, 19, 16, 12, 21, 21, 15, 11, 12, 16, 16, 14, 14, 14, 15, 19, 10, 11, 19, 11, 15, 13, 22, 18, 18, 22, 14, 21, 23, 17, 22, 11, 18, 16, 16, 16, 18, 19, 1 ...
# Plot(...)

# %% [markdown]
# # Exercice 2
#
# Dans cet exercice, vous devrez charger les données météorologiques enregistrées à l'Aéroport Pierre-Elliot-Trudeau à Montréal et afficher les températures annuelles maximales. Les étapes sont les suivantes :
#
# 1. Chargement du fichier de données.
# 2. Récupération des années complètes uniquement.
# 3. Extraction des températures annuelles maximales.
# 4. Affichage des températures annuelles maximales en fonction des années.

# %% [markdown]
# ## 2.1. Chargement du fichier de données
#
# Le chargement du fichier CSV contenant les données se fait en utilisant la fonction `CSV.read()` en ajoutant l'argument `DataFrame`.

# %%
data = CSV.read("meteoMontreal.csv", DataFrame)

first(data,5) # Affiche uniquement les 5 premières lignes de data
# Out:
# 5×37 DataFrame
#  Row │ x        y        STATION_NAME                       STN_ID  CLIMATE_ID ⋯
#      │ Float64  Float64  String                             Int64   Int64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  -73.75  45.4667  MONTREAL/PIERRE ELLIOTT TRUDEAU …    5415             ⋯
#    2 │  -73.75  45.4667  MONTREAL/PIERRE ELLIOTT TRUDEAU …    5415
#    3 │  -73.75  45.4667  MONTREAL/PIERRE ELLIOTT TRUDEAU …    5415
#    4 │  -73.75  45.4667  MONTREAL/PIERRE ELLIOTT TRUDEAU …    5415
#    5 │  -73.75  45.4667  MONTREAL/PIERRE ELLIOTT TRUDEAU …    5415             ⋯
#                                                               33 columns omitted

# %% [markdown]
# ## 2.2 Sélection des colonnes d'intérêts
#
# Sélectionnez les colonnes
# - :LOCAL_YEAR
# - :LOCAL_MONTH
# - :LOCAL_DAY
# - :MAX_TEMPERATURE
#
# du DataFrame avec la fonction `select()` ou `select!()`.

# %%
select!(data, :LOCAL_YEAR, :LOCAL_MONTH, :LOCAL_DAY, :MAX_TEMPERATURE)
# Out:
# 26057×4 DataFrame
#    Row │ LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  MAX_TEMPERATURE
#        │ Int64       Int64        Int64      Float64?
# ───────┼─────────────────────────────────────────────────────
#      1 │       1941            9          1             28.3
#      2 │       1941            9          2             21.7
#      3 │       1941            9          3             26.1
#      4 │       1941            9          4             27.8
#      5 │       1941            9          5             20.6
#      6 │       1941            9          6             27.2
#      7 │       1941            9          7             23.3
#      8 │       1941            9          8             16.1
#      9 │       1941            9          9             17.8
#     10 │       1941            9         10             28.3
#     11 │       1941            9         11             19.4
#    ⋮   │     ⋮            ⋮           ⋮             ⋮
#  26048 │       2013            2          4             -8.2
#  26049 │       2013            2          5             -9.1
#  26050 │       2013            2          6             -6.1
#  26051 │       2013            2          7            -15.5
#  26052 │       2013            2          8            -11.0
#  26053 │       2013            2          9             -6.9
#  26054 │       2013            2         10             -5.6
#  26055 │       2013            2         11              3.5
#  26056 │       2013            2         12              2.4
#  26057 │       2013            2         13              0.8
#                                            26036 rows omitted

# %% [markdown]
# ## 2.3 Récupération des années complètes
#
# Pour que les maxima annuels aient du sens, il faut qu'ils soient pris sur l'année complète. Par exemple, on ne veut pas récupérer le maximum annuel d'une année où l'été n'a pas été enregistré. Pour la station en question, il faut retirer les années 1941 et 2013 qui sont incomplètes.
#
# Retirez du DataFrame les lignes qui correspondent aux années 1941 et 2013.

# %%
# remove rows between 1941 and 2013 from data
filter!(row -> row.:LOCAL_YEAR != 1940 .&& row.:LOCAL_YEAR != 2013, data)
# Out:
# 26013×4 DataFrame
#    Row │ LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  MAX_TEMPERATURE
#        │ Int64       Int64        Int64      Float64?
# ───────┼─────────────────────────────────────────────────────
#      1 │       1941            9          1             28.3
#      2 │       1941            9          2             21.7
#      3 │       1941            9          3             26.1
#      4 │       1941            9          4             27.8
#      5 │       1941            9          5             20.6
#      6 │       1941            9          6             27.2
#      7 │       1941            9          7             23.3
#      8 │       1941            9          8             16.1
#      9 │       1941            9          9             17.8
#     10 │       1941            9         10             28.3
#     11 │       1941            9         11             19.4
#    ⋮   │     ⋮            ⋮           ⋮             ⋮
#  26004 │       2012           12         22              1.4
#  26005 │       2012           12         23             -6.7
#  26006 │       2012           12         24             -7.2
#  26007 │       2012           12         25             -7.1
#  26008 │       2012           12         26             -9.4
#  26009 │       2012           12         27             -3.3
#  26010 │       2012           12         28             -4.2
#  26011 │       2012           12         29             -8.4
#  26012 │       2012           12         30             -9.0
#  26013 │       2012           12         31              0.8
#                                            25992 rows omitted

# %% [markdown]
# ## 2.4 Récupération des données enregistrées
#
# Ignorez les lignes du DataFrame qui correspondent à des températures manquantes avec la fonction `dropmissing()` ou `dropmissing!()`.

# %%
dropmissing!(data, :MAX_TEMPERATURE)
# https://dataframes.juliadata.org/stable/man/missing/
# Out:
# 25979×4 DataFrame
#    Row │ LOCAL_YEAR  LOCAL_MONTH  LOCAL_DAY  MAX_TEMPERATURE
#        │ Int64       Int64        Int64      Float64
# ───────┼─────────────────────────────────────────────────────
#      1 │       1941            9          1             28.3
#      2 │       1941            9          2             21.7
#      3 │       1941            9          3             26.1
#      4 │       1941            9          4             27.8
#      5 │       1941            9          5             20.6
#      6 │       1941            9          6             27.2
#      7 │       1941            9          7             23.3
#      8 │       1941            9          8             16.1
#      9 │       1941            9          9             17.8
#     10 │       1941            9         10             28.3
#     11 │       1941            9         11             19.4
#    ⋮   │     ⋮            ⋮           ⋮             ⋮
#  25970 │       2012           12         22              1.4
#  25971 │       2012           12         23             -6.7
#  25972 │       2012           12         24             -7.2
#  25973 │       2012           12         25             -7.1
#  25974 │       2012           12         26             -9.4
#  25975 │       2012           12         27             -3.3
#  25976 │       2012           12         28             -4.2
#  25977 │       2012           12         29             -8.4
#  25978 │       2012           12         30             -9.0
#  25979 │       2012           12         31              0.8
#                                            25958 rows omitted

# %% [markdown]
# ## 2.5.  Extraction des températures maximales annuelles
#
# Extrayez les maxima annuels de température enregistrés à Montréal. Il y a plusieurs façons de procéder. Je vous propose d'utiliser les fonctions `combine()` et `groupby()` de la librairie *DataFrame* pour manipuler aisément les données dans un DataFrame.

# %%
# maxima annuels de températures
year_combine = groupby(data, :LOCAL_YEAR)
max_annual = combine(year_combine, :MAX_TEMPERATURE => maximum)
# Out:
# 72×2 DataFrame
#  Row │ LOCAL_YEAR  MAX_TEMPERATURE_maximum
#      │ Int64       Float64
# ─────┼─────────────────────────────────────
#    1 │       1941                     28.3
#    2 │       1942                     33.3
#    3 │       1943                     32.2
#    4 │       1944                     35.6
#    5 │       1945                     32.2
#    6 │       1946                     33.9
#    7 │       1947                     33.9
#    8 │       1948                     34.4
#    9 │       1949                     35.0
#   10 │       1950                     31.7
#   11 │       1951                     30.6
#   ⋮  │     ⋮                  ⋮
#   63 │       2003                     33.4
#   64 │       2004                     31.2
#   65 │       2005                     32.8
#   66 │       2006                     34.0
#   67 │       2007                     32.9
#   68 │       2008                     33.3
#   69 │       2009                     32.7
#   70 │       2010                     34.7
#   71 │       2011                     35.6
#   72 │       2012                     33.3
#                             51 rows omitted

# %% [markdown]
# ## 2.6. Affichage des températures annuelles maximales en fonction des années.
#
# Lorsque les données à afficher sont dans un DataFrame, le traçage des graphiques est simple avec Gadfly. Il suffit de mentionner quelle colonne est le $x$ et quelle colonne est le $y$.

# %%
plot(max_annual, x=:LOCAL_YEAR, y=:MAX_TEMPERATURE_maximum, Geom.point, Geom.line,
     Guide.xlabel("Année"), 
     Guide.ylabel("Température maximale"),
     Guide.title("Maxima annuels de températures à Montréal entre 1941 et 2013"))
# Out:
# Plot(...)
